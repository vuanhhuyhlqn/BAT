# %%
import torch
print(torch.__version__)
# Out:
# 2.9.1+cu128

# %%
import torch
print(torch.__file__)
# Out:
# c:\Users\madmo\miniconda3\envs\dl\lib\site-packages\torch\__init__.py

# %%
torch.Tensor()
# Out:
# tensor([])

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7779, 0.6290, 0.3845],
#         [0.7864, 0.7401, 0.1036],
#         [0.6812, 0.7698, 0.3073],
#         [0.9508, 0.8470, 0.3199],
#         [0.2129, 0.3321, 0.4111]])

# %%
from torch_geometric.loader import NeighborLoader
# Out:
# c:\Users\madmo\miniconda3\envs\dl\lib\site-packages\torch_geometric\__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: Could not load this library: C:\Users\madmo\miniconda3\envs\dl\Lib\site-packages\torch_scatter\_version_cuda.pyd
#   import torch_geometric.typing
# c:\Users\madmo\miniconda3\envs\dl\lib\site-packages\torch_geometric\__init__.py:4: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: Could not load this library: C:\Users\madmo\miniconda3\envs\dl\Lib\site-packages\torch_cluster\_version_cuda.pyd
#   import torch_geometric.typing
# c:\Users\madmo\miniconda3\envs\dl\lib\site-packages\torch_geometric\__init__.py:4: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: Could not load this library: C:\Users\madmo\miniconda3\envs\dl\Lib\site-packages\torch_sparse\_version_cuda.pyd
#   import torch_geometric.typing
# ...
