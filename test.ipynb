# %%
import torch

# %%
a = torch.Tensor([1, 2, 3, 4, 5])
mask = torch.BoolTensor([True, False, True, False, False])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 a = torch.Tensor([1, 2, 3, 4, 5])
# ----> 2 mask = torch.BoolTensor([True, False, True, Fal])
#
# NameError: name 'Fal' is not defined
